# %% [markdown]
# <a href="https://colab.research.google.com/github/blerp-836/CS6999-NataliaTheodora/blob/anonFixes/SendSAMIusingPythonRequests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import colab userdata
import os
from google.colab import userdata
os.environ['AWS_ACCESS_KEY_ID'] =userdata.get('AWS_ACCESS_KEY_ID')
os.environ['AWS_SECRET_ACCESS_KEY'] =userdata.get('AWS_SECRET_ACCESS_KEY')
os.environ['AWS_SESSION_TOKEN'] =userdata.get('AWS_SESSION_TOKEN')
os.environ['github_token'] =userdata.get('github-token')

# %%
# !git clone https://blerp-836:$github_token@github.com/blerp-836/pytest_ai4l_scripts.git
# Out:
# Cloning into 'pytest_ai4l_scripts'...
# remote: Enumerating objects: 2980, done.
# remote: Counting objects: 100% (433/433), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 2980 (delta 377), reused 266 (delta 242), pack-reused 2547 (from 1)
# Receiving objects: 100% (2980/2980), 4.09 MiB | 11.87 MiB/s, done.
# Resolving deltas: 100% (2475/2475), done.

# %%
# %%sh
# pip install requests
# pip install sshtunnel psycopg2-binary
# pip install boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.9 MB/s eta 0:00:00
# ...

# %%
os.chdir('/content/pytest_ai4l_scripts/dilab/tests')
from my_secrets import *
from send_event import *
access_token=get_cognito_token()
import json
import os
import datetime

sami_dir='/content/pytest_ai4l_scripts/SAMI/'
# Get the list of JSON files
json_files = [f for f in os.listdir(os.path.join(sami_dir,'fixtures/v1p2')) if f.endswith(".json") and 'Event' in f and 'Envelope' not in f]

def send_sami_event(json_filename,access_token,sami_dir):
    # Load the JSON file
    with open(os.path.join(sami_dir, json_filename), "r") as f:
        json_dict = json.load(f)



    # Call send_caliper_event function
    #start_time = datetime.datetime.now()  # Record start time
    response = send_caliper_event(api_url, access_token, json_dict)
    #end_time = datetime.datetime.now()  # Record end time
    #elapsed_time = (end_time - start_time).total_seconds()  # Calculate elapsed time

    status_code = response.status_code
    response_text = response.text
    print(f"Response for {json_filename}: {status_code}-{response_text}")

    # Assert the status code
    assert status_code == 200, f"Failed for {json_filename}"  # More informative error

    # Extract event ID from the JSON file
    #event_id = json_dict.get("id")
    #assert event_id in response_text, f"Event ID '{event_id}' not found in response for {json_filename}"  # More informative error

    # Assert success message (customize if needed)
    assert "successfully" in response_text, f"Success message not found in response for {json_filename}"  # More informative error

# %%
for json_filename in json_files:
    send_sami_event(json_filename,access_token,os.path.join(sami_dir,'fixtures/v1p2'))
# Out:
# Response for ForumActivityEvent_780_790.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_170_180.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_840_850.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_830_840.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_470_480.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_920_930.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_820_830.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_730_740.json: 200-{"message":"successfully validated caliper events"}
# Response for ForumActivityEvent_710_720.json: 200-{"message":"successfully validated caliper events"}
# ...
